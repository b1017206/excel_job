# %% [markdown]
# # 事前準備
# ・カウントディレクトリには、サンプルデータ（202004_前期.xlsx等）が入っていること

# %% [markdown]
# # ここからデータの整形（excelファイルによって、余分なカラムが入っていたりした為）

# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']
from PIL import Image

# %%
#対象となるxlsxファイルの名前を入れる
name= "201909_後期"
df2 = pd.read_excel('%s.xlsx'%name,header=5)
df2.to_csv('%s.csv'%name)
df2_2 = pd.read_csv('%s.csv'%name)
df2_2
#本当は、動的にしたい（指定したpass内にあるxlsxファイルの分だけのdfを作成したい）↓エラー
#import os
#directory = os.listdir('/Users/ryuumamatsuo/excel_job/*.xlsx')
#data=[]
#for file_name in directory:
#    data.append(pd.read_excel('%s.xlsx'%file_name))
# Out:
#       Unnamed: 0 # 内部コースID         # コース名  \
# 0              0     50912  学習達成度に対する自己評価
# 1              1     50912  学習達成度に対する自己評価
# 2              2     50912  学習達成度に対する自己評価
# 3              3     50912  学習達成度に対する自己評価
# 4              4     50912  学習達成度に対する自己評価
# ...          ...       ...            ...
# 1331        1331       NaN            NaN
# 1332        1332       NaN            NaN
# 1333        1333       NaN            NaN
# 1334        1334       NaN            NaN
# 1335        1335       NaN            NaN
#
#                                                 # リンク情報 # ロール   # ユーザID  \
# 0                                                   NaN   履修生  b1018336
# 1                                                   NaN   履修生  b1020193
# 2                                                   NaN   履修生  b1020197
# 3                                                   NaN   履修生  b1020380
# 4                                                   NaN   履修生  b1021268
# ...                                                 ...   ...       ...
# 1331                                                NaN   NaN       NaN
# 1332  アンケート提出の有無などにより学生を評価する場合は、「#合計点」列のセルには合計点、 「#評...   NaN       NaN
# 1333  「#合計点」、「#評価」列のどちらも空入力の場合は、データ登録されません。0点としてデータ登...   NaN       NaN
# 1334  教員欄は、確認作業用です。自分の欄に合計点、評価や講評を入れて、どのように表示されるか試すこ...   NaN       NaN
# 1335  採点作業が終了したら、このシートを保存してからmanabaにアップロードしてください。（提出...   NaN       NaN
#
#          # 学籍番号   # 氏名        # 氏名（英語）           # メールアドレス  ...  \
# 0     1018336.0  函館　未来  Mirai Hakodate  b1018336@fun.ac.jp  ...
# 1     1020193.0  函館　未来  Mirai Hakodate  b1020193@fun.ac.jp  ...
# 2     1020197.0  函館　未来  Mirai Hakodate  b1020197@fun.ac.jp  ...
# 3     1020380.0  函館　未来  Mirai Hakodate  b1020380@fun.ac.jp  ...
# 4     1021268.0  函館　未来  Mirai Hakodate  b1021268@fun.ac.jp  ...
# ...         ...    ...             ...                 ...  ...
# 1331        NaN    NaN             NaN                 NaN  ...
# 1332        NaN    NaN             NaN                 NaN  ...
# 1333        NaN    NaN             NaN                 NaN  ...
# 1334        NaN    NaN             NaN                 NaN  ...
# 1335        NaN    NaN             NaN                 NaN  ...
#
#       １．システム情報科学に関する高い専門能力（コース専門能力）  １．システム情報科学に関する高い専門能力（卒業研究）  \
# 0                               6.0                         7.0
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               5.0                         4.0
# ...                             ...                         ...
# 1331                            NaN                         NaN
# 1332                            NaN                         NaN
# 1333                            NaN                         NaN
# 1334                            NaN                         NaN
# 1335                            NaN                         NaN
#
#       ２．研究的態度を支える問題探究力・構想力 ３．共創のための情報表現能力・チームワーク力 ４．自律的に学び続けるためのメタ学習力  \
# 0                      6.0                    7.0                 7.0
# 1                      NaN                    NaN                 NaN
# 2                      NaN                    NaN                 NaN
# 3                      NaN                    NaN                 NaN
# 4                      5.0                    6.0                 6.0
# ...                    ...                    ...                 ...
# 1331                   NaN                    NaN                 NaN
# 1332                   NaN                    NaN                 NaN
# 1333                   NaN                    NaN                 NaN
# 1334                   NaN                    NaN                 NaN
# 1335                   NaN                    NaN                 NaN
#
#      ５．専門家として持つべき人間性                今学期の目標            目標達成のための計画  Unnamed: 26  \
# 0                5.0  選択科目の習得\r\n研究分野の現状把握  予復習\r\n新規論文のチェック\r\n          NaN
# 1                NaN                   NaN                   NaN          NaN
# 2                NaN                   NaN                   NaN          NaN
# 3                NaN                   NaN                   NaN          NaN
# 4                7.0      卒業研究をより良い形で完結させる   日々より良い方法を模索し、研究していく          NaN
# ...              ...                   ...                   ...          ...
# 1331             NaN                   NaN                   NaN          NaN
# 1332             NaN                   NaN                   NaN          NaN
# 1333             NaN                   NaN                   NaN          NaN
# 1334             NaN                   NaN                   NaN          NaN
# 1335             NaN                   NaN                   NaN          NaN
#
#       Unnamed: 27
# 0       1026528.0
# 1       1028385.0
# 2       1028389.0
# 3       1028572.0
# 4       1029460.0
# ...           ...
# 1331          NaN
# 1332          NaN
# 1333          NaN
# 1334          NaN
# 1335          NaN
#
# [1336 rows x 29 columns]

# %%
headertitle=list(df2_2.columns)
headertitle
# Out:
# ['Unnamed: 0',
#  '# 内部コースID',
#  '# コース名',
#  '# リンク情報',
#  '# ロール',
#  '# ユーザID',
#  '# 学籍番号',
#  '# 氏名',
#  '# 氏名（英語）',
#  '# メールアドレス',
#  '# 合計点',
#  '# 評価',
#  '# 講評',
#  '# 経過時間',
#  '# 提出',
#  '# 提出日時',
#  '学年',
#  '所属コース',
#  '１．システム情報科学に関する高い専門能力（コース共通）',
#  '１．システム情報科学に関する高い専門能力（コース専門能力）',
#  '１．システム情報科学に関する高い専門能力（卒業研究）',
#  '２．研究的態度を支える問題探究力・構想力',
#  '３．共創のための情報表現能力・チームワーク力',
#  '４．自律的に学び続けるためのメタ学習力',
#  '５．専門家として持つべき人間性',
#  '今学期の目標',
#  '目標達成のための計画',
#  'Unnamed: 26',
#  'Unnamed: 27']

# %%
#削除したいカラム名を抽出
headertitle_in = [s for s in headertitle if 'Unnamed' in s]
print(headertitle_in)
# Out:
# ['Unnamed: 0', 'Unnamed: 26', 'Unnamed: 27']

# %%
#条件にマッチしたcolumnsを削除
data_frame = df2_2.drop(columns=headertitle_in)
data_frame
# Out:
#      # 内部コースID         # コース名  \
# 0        50912  学習達成度に対する自己評価
# 1        50912  学習達成度に対する自己評価
# 2        50912  学習達成度に対する自己評価
# 3        50912  学習達成度に対する自己評価
# 4        50912  学習達成度に対する自己評価
# ...        ...            ...
# 1331       NaN            NaN
# 1332       NaN            NaN
# 1333       NaN            NaN
# 1334       NaN            NaN
# 1335       NaN            NaN
#
#                                                 # リンク情報 # ロール   # ユーザID  \
# 0                                                   NaN   履修生  b1018336
# 1                                                   NaN   履修生  b1020193
# 2                                                   NaN   履修生  b1020197
# 3                                                   NaN   履修生  b1020380
# 4                                                   NaN   履修生  b1021268
# ...                                                 ...   ...       ...
# 1331                                                NaN   NaN       NaN
# 1332  アンケート提出の有無などにより学生を評価する場合は、「#合計点」列のセルには合計点、 「#評...   NaN       NaN
# 1333  「#合計点」、「#評価」列のどちらも空入力の場合は、データ登録されません。0点としてデータ登...   NaN       NaN
# 1334  教員欄は、確認作業用です。自分の欄に合計点、評価や講評を入れて、どのように表示されるか試すこ...   NaN       NaN
# 1335  採点作業が終了したら、このシートを保存してからmanabaにアップロードしてください。（提出...   NaN       NaN
#
#          # 学籍番号   # 氏名        # 氏名（英語）           # メールアドレス  # 合計点  ...  所属コース  \
# 0     1018336.0  函館　未来  Mirai Hakodate  b1018336@fun.ac.jp    NaN  ...    NaN
# 1     1020193.0  函館　未来  Mirai Hakodate  b1020193@fun.ac.jp    NaN  ...    NaN
# 2     1020197.0  函館　未来  Mirai Hakodate  b1020197@fun.ac.jp    NaN  ...    NaN
# 3     1020380.0  函館　未来  Mirai Hakodate  b1020380@fun.ac.jp    NaN  ...    NaN
# 4     1021268.0  函館　未来  Mirai Hakodate  b1021268@fun.ac.jp    NaN  ...    NaN
# ...         ...    ...             ...                 ...    ...  ...    ...
# 1331        NaN    NaN             NaN                 NaN    NaN  ...    NaN
# 1332        NaN    NaN             NaN                 NaN    NaN  ...    NaN
# 1333        NaN    NaN             NaN                 NaN    NaN  ...    NaN
# 1334        NaN    NaN             NaN                 NaN    NaN  ...    NaN
# 1335        NaN    NaN             NaN                 NaN    NaN  ...    NaN
#
#       １．システム情報科学に関する高い専門能力（コース共通） １．システム情報科学に関する高い専門能力（コース専門能力）  \
# 0                             6.0                           6.0
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             6.0                           5.0
# ...                           ...                           ...
# 1331                          NaN                           NaN
# 1332                          NaN                           NaN
# 1333                          NaN                           NaN
# 1334                          NaN                           NaN
# 1335                          NaN                           NaN
#
#      １．システム情報科学に関する高い専門能力（卒業研究） ２．研究的態度を支える問題探究力・構想力  ３．共創のための情報表現能力・チームワーク力  \
# 0                           7.0                  6.0                     7.0
# 1                           NaN                  NaN                     NaN
# 2                           NaN                  NaN                     NaN
# 3                           NaN                  NaN                     NaN
# 4                           4.0                  5.0                     6.0
# ...                         ...                  ...                     ...
# 1331                        NaN                  NaN                     NaN
# 1332                        NaN                  NaN                     NaN
# 1333                        NaN                  NaN                     NaN
# 1334                        NaN                  NaN                     NaN
# 1335                        NaN                  NaN                     NaN
#
#       ４．自律的に学び続けるためのメタ学習力  ５．専門家として持つべき人間性                今学期の目標  \
# 0                     7.0              5.0  選択科目の習得\r\n研究分野の現状把握
# 1                     NaN              NaN                   NaN
# 2                     NaN              NaN                   NaN
# 3                     NaN              NaN                   NaN
# 4                     6.0              7.0      卒業研究をより良い形で完結させる
# ...                   ...              ...                   ...
# 1331                  NaN              NaN                   NaN
# 1332                  NaN              NaN                   NaN
# 1333                  NaN              NaN                   NaN
# 1334                  NaN              NaN                   NaN
# 1335                  NaN              NaN                   NaN
#
#                 目標達成のための計画
# 0     予復習\r\n新規論文のチェック\r\n
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4      日々より良い方法を模索し、研究していく
# ...                    ...
# 1331                   NaN
# 1332                   NaN
# 1333                   NaN
# 1334                   NaN
# 1335                   NaN
#
# [1336 rows x 26 columns]

# %%
#excel化してカレントディレクトリに保存
data_frame.to_excel('%s_ver2.xlsx'%name)

# %% [markdown]
# # ここからが出力

# %%
df_new = pd.read_excel('%s_ver2.xlsx'%name)
df3=df_new[['１．システム情報科学に関する高い専門能力（コース共通）',
 '１．システム情報科学に関する高い専門能力（コース専門能力）',
 '１．システム情報科学に関する高い専門能力（卒業研究）',
 '２．研究的態度を支える問題探究力・構想力',
 '３．共創のための情報表現能力・チームワーク力',
 '４．自律的に学び続けるためのメタ学習力',
 '５．専門家として持つべき人間性',]]
df3
# Out:
#       １．システム情報科学に関する高い専門能力（コース共通）  １．システム情報科学に関する高い専門能力（コース専門能力）  \
# 0                             6.0                            6.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             6.0                            5.0
# ...                           ...                            ...
# 1331                          NaN                            NaN
# 1332                          NaN                            NaN
# 1333                          NaN                            NaN
# 1334                          NaN                            NaN
# 1335                          NaN                            NaN
#
#       １．システム情報科学に関する高い専門能力（卒業研究）  ２．研究的態度を支える問題探究力・構想力  \
# 0                            7.0                   6.0
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            4.0                   5.0
# ...                          ...                   ...
# 1331                         NaN                   NaN
# 1332                         NaN                   NaN
# 1333                         NaN                   NaN
# 1334                         NaN                   NaN
# 1335                         NaN                   NaN
#
#       ３．共創のための情報表現能力・チームワーク力  ４．自律的に学び続けるためのメタ学習力  ５．専門家として持つべき人間性
# 0                        7.0                  7.0              5.0
# 1                        NaN                  NaN              NaN
# 2                        NaN                  NaN              NaN
# 3                        NaN                  NaN              NaN
# 4                        6.0                  6.0              7.0
# ...                      ...                  ...              ...
# 1331                     NaN                  NaN              NaN
# 1332                     NaN                  NaN              NaN
# 1333                     NaN                  NaN              NaN
# 1334                     NaN                  NaN              NaN
# 1335                     NaN                  NaN              NaN
#
# [1336 rows x 7 columns]

# %%
#↑の０行目を取得
data=df3.iloc[0,[0,1,2,3,4,5,6]].tolist()
data
# Out:
# [6.0, 6.0, 7.0, 6.0, 7.0, 7.0, 5.0]

# %%
# グラフの描画先の準備
fig = plt.figure(figsize=(40,10), dpi=100)
left = np.array(['１．システム情報科学に関する高い専門能力（コース共通）',
 '１．システム情報科学に関する高い専門能力（コース専門能力）',
 '１．システム情報科学に関する高い専門能力（卒業研究）',
 '２．研究的態度を支える問題探究力・構想力',
 '３．共創のための情報表現能力・チームワーク力',
 '４．自律的に学び続けるためのメタ学習力',
 '５．専門家として持つべき人間性'])
height=np.array(data)
plt.bar(left, height, align="center")
# 作成したチャートを画像出力
fig.savefig('graph.png')
# 出力したgraph.pngをout.xlsxに貼り付ける
wb = openpyxl.Workbook()
ws = wb.worksheets[0]
img = openpyxl.drawing.image.Image('graph.png')
ws.add_image(img, 'B12')
wb.save('out.xlsx')
plt.close()
